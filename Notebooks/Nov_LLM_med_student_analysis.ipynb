# %%
import pandas as pd
import numpy as np
import functools as ft

# %%
def process_csv_df(csv):
    df = pd.read_csv(csv, index_col=0, header=1)
    df = df[1:]
    return df

# %%
nov_llm_use_df = process_csv_df("Medical Students' Use of LLMs_November 18, 2024_21.00.csv")

# %%
feb_llm_use_df = process_csv_df("Medical Students' Use of LLMs_February 19, 2025_11.01.csv")

# %%
##Dropping columns that will not be used/reference for future code
nov_llm_cols_drop = ['End Date', 'Recipient Email', 'Distribution Channel', 'Response Type', 'IP Address', 'Duration (in seconds)', 'External Data Reference', 'Location Latitude', 'Location Longitude', 
                'Response Type', 'Progress', 'Response ID', 'Recorded Date', 'Recipient Last Name', 'Recipient First Name', 'List of Countries', 'What is your gender? - Prefer to self-describe - Text',
                'How would you describe your race? - Other - Text', 
                '''DESCRIPTION: You are invited to participate in a research study evaluating medical students' perspectives and usage of AI-based language models in practice. You will be asked to answer questions about if you have used AI large language models in practice, which AI large language models you have used, how you have used AI large language models, and information about your medical school. All survey responses are captured anonymously.\n\nTIME INVOLVEMENT: Your participation will take approximately 15 minutes.\n\nRISKS AND BENEFITS: The risks associated with this study are no foreseeable risks associated with completing this survey. We cannot and do not guarantee or promise that you will receive any benefits from completing this survey. However, by completing this survey, you will be contributing to our understanding of how medical students are using large language models in medical school and clinical settings. Your decision whether or not to participate in this study will not affect your academic performance.\n\nPAYMENTS: You will not receive any payment for completing this survey.\n\nPARTICIPANT'S RIGHTS: If you have read this form and have decided to participate in this project, please understand your participation is voluntary and you have the right to withdraw your consent or discontinue participation at any time without penalty or loss of benefits to which you are otherwise entitled. The alternative is not to participate. You have the right to refuse to answer particular questions. The results of this research study may be presented at scientific or professional meetings or published in scientific journals. Your individual privacy will be maintained in all published and written data resulting from the study. All survey responses will be recorded anonymously.\n\nCONTACT INFORMATION:\nQuestions? Please contact Dr. Jenna Lester at 415-353-7800. If you have questions or concerns about your rights as a research participant, you can call the UCSF Institutional Review Board at 415-476-1814.\n\nPlease print a copy of this page for your records.\n\nIf you agree to participate in this research, please click on the "Agree" button.'''

]

nov_llm_use_df_clean = dec_llm_use_df.drop(columns=nov_llm_cols_drop)

# %%
##Dropping columns that will not be used/reference for future code
feb_llm_cols_drop = ['End Date', 'Recipient Email', 'Distribution Channel', 'Response Type', 'IP Address', 'Duration (in seconds)', 'External Data Reference', 'Location Latitude', 'Location Longitude', 
                'Response Type', 'Progress', 'Response ID', 'Recorded Date', 'Recipient Last Name', 'Recipient First Name', 'List of Countries', 'What is your gender? - Prefer to self-describe - Text',
                'How would you describe your race? - Other - Text', 
                '''DESCRIPTION: You are invited to participate in a research study evaluating medical students' perspectives and usage of AI-based language models in practice. You will be asked to answer questions about if you have used AI large language models in practice, which AI large language models you have used, how you have used AI large language models, and information about your medical school. All survey responses are captured anonymously.\n\nTIME INVOLVEMENT: Your participation will take approximately 15 minutes.\n\nRISKS AND BENEFITS: The risks associated with this study are no foreseeable risks associated with completing this survey. We cannot and do not guarantee or promise that you will receive any benefits from completing this survey. However, by completing this survey, you will be contributing to our understanding of how medical students are using large language models in medical school and clinical settings. Your decision whether or not to participate in this study will not affect your academic performance.\n\nPAYMENTS: You will not receive any payment for completing this survey.\n\nPARTICIPANT'S RIGHTS: If you have read this form and have decided to participate in this project, please understand your participation is voluntary and you have the right to withdraw your consent or discontinue participation at any time without penalty or loss of benefits to which you are otherwise entitled. The alternative is not to participate. You have the right to refuse to answer particular questions. The results of this research study may be presented at scientific or professional meetings or published in scientific journals. Your individual privacy will be maintained in all published and written data resulting from the study. All survey responses will be recorded anonymously.\n\nCONTACT INFORMATION:\nQuestions? Please contact Dr. Jenna Lester at 415-353-7800. If you have questions or concerns about your rights as a research participant, you can call the UCSF Institutional Review Board at 415-476-1814.\n\nPlease print a copy of this page for your records.\n\nIf you agree to participate in this research, please click on the "Agree" button.'''

]

feb_llm_use_df_clean = feb_llm_use_df.drop(columns=feb_llm_cols_drop)

# %%
##Verifying total number of people in the survey -- 118
nov_llm_use_df_clean_118 = nov_llm_use_df_clean[nov_llm_use_df_clean['Are you a medical student?'] == 'Yes']

# %%
##Verifying total number of people in the survey -- 118
feb_llm_use_df_clean_118 = feb_llm_use_df_clean[feb_llm_use_df_clean['Are you a medical student?'] == 'Yes']
len(feb_llm_use_df_clean_118)
# Out:
# 120

# %%
##Dropping second group of columns that include other text answers (keeping only columns that are selection based answers)
sec_col_grp_drop = ['Do you have any concerns about AI-based language models? (Check all that apply) - Other - Text',  'Which of the following large language models have you used? (Check all that apply) - Other - Text', 'What have you used AI-based language models for? (Check all that apply) - Other - Text',
                    'Are you currently in the pre-clinical or clinical portion of your medical school? - Other - Text'


]

nov_llm_use_df_clean_118.drop(columns=sec_col_grp_drop)
# Out:
#                     Finished User Language Are you a medical student?  \
# Start Date
# 2024-03-05 20:06:43     True            EN                        Yes
# 2024-03-11 13:31:43     True            EN                        Yes
# 2024-03-11 16:27:36     True            EN                        Yes
# 2024-03-11 23:04:21     True            EN                        Yes
# 2024-03-17 19:24:27     True            EN                        Yes
# ...                      ...           ...                        ...
# 2024-11-01 06:49:15     True            EN                        Yes
# 2024-10-31 19:43:47     True            EN                        Yes
# 2024-10-31 19:23:49    False            EN                        Yes
# 2024-11-27 15:49:32    False            EN                        Yes
# 2025-01-13 08:18:16    False            EN                        Yes
#
#                     Is your medical school in the U.S. / a U.S. territory?  \
# Start Date
# 2024-03-05 20:06:43                                                Yes
# 2024-03-11 13:31:43                                                Yes
# 2024-03-11 16:27:36                                                Yes
# 2024-03-11 23:04:21                                                Yes
# 2024-03-17 19:24:27                                                Yes
# ...                                                                ...
# 2024-11-01 06:49:15                                                Yes
# 2024-10-31 19:43:47                                                Yes
# 2024-10-31 19:23:49                                                Yes
# 2024-11-27 15:49:32                                                 No
# 2025-01-13 08:18:16                                                Yes
#
#                     50 States, D.C. and Puerto Rico  \
# Start Date
# 2024-03-05 20:06:43                      California
# 2024-03-11 13:31:43                      California
# 2024-03-11 16:27:36                      California
# 2024-03-11 23:04:21                      California
# 2024-03-17 19:24:27                      California
# ...                                             ...
# 2024-11-01 06:49:15                       Tennessee
# 2024-10-31 19:43:47                       Tennessee
# 2024-10-31 19:23:49                        Arkansas
# 2024-11-27 15:49:32                             NaN
# 2025-01-13 08:18:16                             NaN
#
#                     What type of community is your medical school in?  \
# Start Date
# 2024-03-05 20:06:43                                             Urban
# 2024-03-11 13:31:43                                             Urban
# 2024-03-11 16:27:36                                             Urban
# 2024-03-11 23:04:21                                             Urban
# 2024-03-17 19:24:27                                             Urban
# ...                                                               ...
# 2024-11-01 06:49:15                                             Urban
# 2024-10-31 19:43:47                                             Urban
# 2024-10-31 19:23:49                                             Urban
# 2024-11-27 15:49:32                                             Urban
# 2025-01-13 08:18:16                                               NaN
#
#                     Are you currently in the pre-clinical or clinical portion of your medical school? - Selected Choice  \
# Start Date
# 2024-03-05 20:06:43                                           Clinical
# 2024-03-11 13:31:43                                           Clinical
# 2024-03-11 16:27:36                                           Clinical
# 2024-03-11 23:04:21                                           Clinical
# 2024-03-17 19:24:27                                           Clinical
# ...                                                                ...
# 2024-11-01 06:49:15                                           Clinical
# 2024-10-31 19:43:47                                           Clinical
# 2024-10-31 19:23:49                                           Clinical
# 2024-11-27 15:49:32                                       Pre-clinical
# 2025-01-13 08:18:16                                                NaN
#
#                     Have you used a large language model (e.g., ChatGPT, Doximity GPT, Google Bard, GPT-4, Bing Chat)?  \
# Start Date
# 2024-03-05 20:06:43                                                Yes
# 2024-03-11 13:31:43                                                Yes
# 2024-03-11 16:27:36                                                Yes
# 2024-03-11 23:04:21                                                 No
# 2024-03-17 19:24:27                                                 No
# ...                                                                ...
# 2024-11-01 06:49:15                                                Yes
# 2024-10-31 19:43:47                                                Yes
# 2024-10-31 19:23:49                                                NaN
# 2024-11-27 15:49:32                                                Yes
# 2025-01-13 08:18:16                                                NaN
#
#                     Do you have any concerns about AI-based language models? (Check all that apply) - Selected Choice  \
# Start Date
# 2024-03-05 20:06:43  Concerns about privacy,Concerns about accuracy...
# 2024-03-11 13:31:43  Concerns about accuracy,Concerns about bias,Co...
# 2024-03-11 16:27:36  Concerns about privacy,Concerns about accuracy...
# 2024-03-11 23:04:21  Concerns about privacy,Concerns about accuracy...
# 2024-03-17 19:24:27  Concerns about privacy,Concerns about accuracy...
# ...                                                                ...
# 2024-11-01 06:49:15                      Concerns about accuracy,Other
# 2024-10-31 19:43:47        Concerns about accuracy,Concerns about bias
# 2024-10-31 19:23:49                                                NaN
# 2024-11-27 15:49:32                                                NaN
# 2025-01-13 08:18:16                                                NaN
#
#                     How likely are you to use AI-based language models in the future?  \
# Start Date
# 2024-03-05 20:06:43                                    Somewhat likely
# 2024-03-11 13:31:43                                    Somewhat likely
# 2024-03-11 16:27:36                                   Extremely likely
# 2024-03-11 23:04:21                                  Somewhat unlikely
# 2024-03-17 19:24:27                                  Somewhat unlikely
# ...                                                                ...
# 2024-11-01 06:49:15                                   Extremely likely
# 2024-10-31 19:43:47                                    Somewhat likely
# 2024-10-31 19:23:49                                                NaN
# 2024-11-27 15:49:32                                                NaN
# 2025-01-13 08:18:16                                                NaN
#
#                     Do you have any final comments about AI-based language models?  \
# Start Date
# 2024-03-05 20:06:43                                                NaN
# 2024-03-11 13:31:43                                                NaN
# 2024-03-11 16:27:36                                                NaN
# 2024-03-11 23:04:21                                                NaN
# 2024-03-17 19:24:27                                                NaN
# ...                                                                ...
# 2024-11-01 06:49:15  we love smart texts and dot phrases. we hate p...
# 2024-10-31 19:43:47                                                NaN
# 2024-10-31 19:23:49                                                NaN
# 2024-11-27 15:49:32                                                NaN
# 2025-01-13 08:18:16                                                NaN
#
#                     What is your gender? - Selected Choice  \
# Start Date
# 2024-03-05 20:06:43                                 Female
# 2024-03-11 13:31:43                                   Male
# 2024-03-11 16:27:36                                   Male
# 2024-03-11 23:04:21                                 Female
# 2024-03-17 19:24:27                                   Male
# ...                                                    ...
# 2024-11-01 06:49:15                                 Female
# 2024-10-31 19:43:47                                   Male
# 2024-10-31 19:23:49                                    NaN
# 2024-11-27 15:49:32                                    NaN
# 2025-01-13 08:18:16                                    NaN
#
#                     How would you describe your race? - Selected Choice  \
# Start Date
# 2024-03-05 20:06:43                                              Other
# 2024-03-11 13:31:43                                 White or Caucasian
# 2024-03-11 16:27:36                                              Asian
# 2024-03-11 23:04:21                                 White or Caucasian
# 2024-03-17 19:24:27                                              Asian
# ...                                                                ...
# 2024-11-01 06:49:15                                 White or Caucasian
# 2024-10-31 19:43:47                          Black or African American
# 2024-10-31 19:23:49                                                NaN
# 2024-11-27 15:49:32                                                NaN
# 2025-01-13 08:18:16                                                NaN
#
#                     Are you of Spanish, Hispanic, or Latino origin?  \
# Start Date
# 2024-03-05 20:06:43                                              No
# 2024-03-11 13:31:43                                              No
# 2024-03-11 16:27:36                                              No
# 2024-03-11 23:04:21                                              No
# 2024-03-17 19:24:27                                              No
# ...                                                             ...
# 2024-11-01 06:49:15                                              No
# 2024-10-31 19:43:47                                              No
# 2024-10-31 19:23:49                                             NaN
# 2024-11-27 15:49:32                                             NaN
# 2025-01-13 08:18:16                                             NaN
#
#                     Which of the following large language models have you used? (Check all that apply) - Selected Choice  \
# Start Date
# 2024-03-05 20:06:43                                            ChatGPT
# 2024-03-11 13:31:43                                            ChatGPT
# 2024-03-11 16:27:36                                            ChatGPT
# 2024-03-11 23:04:21                                                NaN
# 2024-03-17 19:24:27                                                NaN
# ...                                                                ...
# 2024-11-01 06:49:15                                            ChatGPT
# 2024-10-31 19:43:47                                            ChatGPT
# 2024-10-31 19:23:49                                                NaN
# 2024-11-27 15:49:32                                                NaN
# 2025-01-13 08:18:16                                                NaN
#
#                     What have you used AI-based language models for? (Check all that apply) - Selected Choice  \
# Start Date
# 2024-03-05 20:06:43                                              Other
# 2024-03-11 13:31:43            Studying: Answer questions about topics
# 2024-03-11 16:27:36   Studying: Generate practice questions/flashcards
# 2024-03-11 23:04:21                                                NaN
# 2024-03-17 19:24:27                                                NaN
# ...                                                                ...
# 2024-11-01 06:49:15  Generate response to a patient (email/letter/t...
# 2024-10-31 19:43:47  Generate differential diagnoses,Generate respo...
# 2024-10-31 19:23:49                                                NaN
# 2024-11-27 15:49:32                                                NaN
# 2025-01-13 08:18:16                                                NaN
#
#                     How often are you using AI-based language models?  \
# Start Date
# 2024-03-05 20:06:43                                           Monthly
# 2024-03-11 13:31:43                                           Monthly
# 2024-03-11 16:27:36                                A few times/rarely
# 2024-03-11 23:04:21                                               NaN
# 2024-03-17 19:24:27                                               NaN
# ...                                                               ...
# 2024-11-01 06:49:15                                            Weekly
# 2024-10-31 19:43:47                                           Monthly
# 2024-10-31 19:23:49                                               NaN
# 2024-11-27 15:49:32                                               NaN
# 2025-01-13 08:18:16                                               NaN
#
#                     How accurate did you find AI-based language models?  \
# Start Date
# 2024-03-05 20:06:43                 Somewhat accurate (a few mistakes)
# 2024-03-11 13:31:43                 Somewhat accurate (a few mistakes)
# 2024-03-11 16:27:36                 Somewhat accurate (a few mistakes)
# 2024-03-11 23:04:21                                                NaN
# 2024-03-17 19:24:27                                                NaN
# ...                                                                ...
# 2024-11-01 06:49:15  Neither accurate nor inaccurate (a number of m...
# 2024-10-31 19:43:47                 Somewhat accurate (a few mistakes)
# 2024-10-31 19:23:49                                                NaN
# 2024-11-27 15:49:32                                                NaN
# 2025-01-13 08:18:16                                                NaN
#
#                     In a single output given to you by an AI-based language model, on average how many edits have you needed to make?  \
# Start Date
# 2024-03-05 20:06:43                    Moderate editing (5-10 changes)
# 2024-03-11 13:31:43                    Moderate editing (5-10 changes)
# 2024-03-11 16:27:36              Minimal editing (less than 5 changes)
# 2024-03-11 23:04:21                                                NaN
# 2024-03-17 19:24:27                                                NaN
# ...                                                                ...
# 2024-11-01 06:49:15                    Moderate editing (5-10 changes)
# 2024-10-31 19:43:47              Minimal editing (less than 5 changes)
# 2024-10-31 19:23:49                                                NaN
# 2024-11-27 15:49:32                                                NaN
# 2025-01-13 08:18:16                                                NaN
#
#                     How do you think AI-based language models are impacting your learning?
# Start Date
# 2024-03-05 20:06:43                                          No impact
# 2024-03-11 13:31:43                                         Positively
# 2024-03-11 16:27:36                                         Positively
# 2024-03-11 23:04:21                                                NaN
# 2024-03-17 19:24:27                                                NaN
# ...                                                                ...
# 2024-11-01 06:49:15                                         Positively
# 2024-10-31 19:43:47                                         Positively
# 2024-10-31 19:23:49                                                NaN
# 2024-11-27 15:49:32                                                NaN
# 2025-01-13 08:18:16                                                NaN
#
# [120 rows x 20 columns]

# %%
##Dropping second group of columns that include other text answers (keeping only columns that are selection based answers)
sec_col_grp_drop = ['Do you have any concerns about AI-based language models? (Check all that apply) - Other - Text',  'Which of the following large language models have you used? (Check all that apply) - Other - Text', 'What have you used AI-based language models for? (Check all that apply) - Other - Text',
                    'Are you currently in the pre-clinical or clinical portion of your medical school? - Other - Text'


]

feb_llm_use_df_clean_118.drop(columns=sec_col_grp_drop)

# %%
##Checking / filtering for those who have completed survey

nov_llm_use_df_clean_118_comp= nov_llm_use_df_clean_118.loc[nov_llm_use_df_clean_118['Finished'] == 'True']
##The suffix comp includes only "completed" survey responses in df. Non-comp includes non-complete survey responses

# len(nov_llm_use_df_clean_118_comp)
##This shows how many people are in the completed survey df - 86 people have completed survey

##Exporting results of only those who have completed survey
nov_llm_use_df_clean_118_comp.to_csv("nov_patient_llm_use_df_clean_complete.csv", encoding='utf-8', index=False)

# %%
##Checking / filtering for those who have completed survey

feb_llm_use_df_clean_118_comp= feb_llm_use_df_clean_118.loc[feb_llm_use_df_clean_118['Finished'] == 'True']
##The suffix comp includes only "completed" survey responses in df. Non-comp includes non-complete survey responses

##Exporting results of only those who have completed survey
feb_llm_use_df_clean_118_comp.to_csv("feb_patient_llm_use_df_clean_complete.csv", encoding='utf-8', index=False)

# %%
## Renaming neither accurate nor inaccurate response
mask = nov_llm_use_df_clean_118_comp["How accurate did you find AI-based language models?"] == "Neither accurate nor inaccurate (a number of mistakes, but still useable)"
nov_llm_use_df_clean_118_comp.loc[mask, "How accurate did you find AI-based language models?"] = "Neither accurate nor inaccurate"
# Out:
# /Users/vivianutti/Library/Python/3.7/lib/python/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/vivianutti/Library/Python/3.7/lib/python/site-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
## Renaming neither accurate nor inaccurate response
mask = feb_llm_use_df_clean_118_comp["How accurate did you find AI-based language models?"] == "Neither accurate nor inaccurate (a number of mistakes, but still useable)"
feb_llm_use_df_clean_118_comp.loc[mask, "How accurate did you find AI-based language models?"] = "Neither accurate nor inaccurate"
mask2 = feb_llm_use_df_clean_118["How accurate did you find AI-based language models?"] == "Neither accurate nor inaccurate (a number of mistakes, but still useable)"

feb_llm_use_df_clean_118.loc[mask2, "How accurate did you find AI-based language models?"] = "Neither accurate nor inaccurate"
# Out:
# /Users/vivianutti/Library/Python/3.7/lib/python/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/vivianutti/Library/Python/3.7/lib/python/site-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
opinion_cols_of_interest = [ 
       'Have you used a large language model (e.g., ChatGPT, Doximity GPT, Google Bard, GPT-4, Bing Chat)?',
       'How often are you using AI-based language models?',
       'How likely are you to use AI-based language models in the future?',
       'In a single output given to you by an AI-based language model, on average how many edits have you needed to make?',
       'How do you think AI-based language models are impacting your learning?',
       'Which of the following large language models have you used? (Check all that apply) - Selected Choice',
       'How accurate did you find AI-based language models?',
]

demo_cols_of_interest = [ 'What type of community is your medical school in?', 'Is your medical school in the U.S. / a U.S. territory?',
                          'Are you currently in the pre-clinical or clinical portion of your medical school? - Selected Choice',          
                                    'What is your gender? - Selected Choice', 'Are you of Spanish, Hispanic, or Latino origin?',
                                    'How would you describe your race? - Selected Choice'
                                    ]

##Creating smaller analysis dfs based on relevant columns (demographic based columns)
demographics_nov_llm_use_df_clean_118_comp = nov_llm_use_df_clean_118_comp[demo_cols_of_interest]
demographics_nov_llm_use_df_clean_118 = nov_llm_use_df_clean_118[demo_cols_of_interest]

##Creating smaller analysis dfs based on relevant columns (opinion based columns)
op_nov_llm_use_df_clean_118_comp = nov_llm_use_df_clean_118_comp[opinion_cols_of_interest]
op_nov_llm_use_df_clean_118_non_comp = nov_llm_use_df_clean_118[opinion_cols_of_interest]

# %%
opinion_cols_of_interest = [ 
       'Have you used a large language model (e.g., ChatGPT, Doximity GPT, Google Bard, GPT-4, Bing Chat)?',
       'How often are you using AI-based language models?',
       'How likely are you to use AI-based language models in the future?',
       'In a single output given to you by an AI-based language model, on average how many edits have you needed to make?',
       'How do you think AI-based language models are impacting your learning?',
       'Which of the following large language models have you used? (Check all that apply) - Selected Choice',
       'How accurate did you find AI-based language models?',
]

demo_cols_of_interest = [ 'What type of community is your medical school in?', 'Is your medical school in the U.S. / a U.S. territory?',
                          'Are you currently in the pre-clinical or clinical portion of your medical school? - Selected Choice',          
                                    'What is your gender? - Selected Choice', 'Are you of Spanish, Hispanic, or Latino origin?',
                                    'How would you describe your race? - Selected Choice'
                                    ]

##Creating smaller analysis dfs based on relevant columns (demographic based columns)
demographics_feb_llm_use_df_clean_118_comp = feb_llm_use_df_clean_118_comp[demo_cols_of_interest]
demographics_feb_llm_use_df_clean_118 = feb_llm_use_df_clean_118[demo_cols_of_interest]

##Creating smaller analysis dfs based on relevant columns (opinion based columns)
op_feb_llm_use_df_clean_118_comp = feb_llm_use_df_clean_118_comp[opinion_cols_of_interest]
op_feb_llm_use_df_clean_118_non_comp = feb_llm_use_df_clean_118[opinion_cols_of_interest]

# %%
clinical_perspective_feb_llm_use_df_clean_118
# Out:
#                     Have you used a large language model (e.g., ChatGPT, Doximity GPT, Google Bard, GPT-4, Bing Chat)?  \
# Start Date
# 2024-03-05 20:06:43                                                Yes
# 2024-03-11 13:31:43                                                Yes
# 2024-03-11 16:27:36                                                Yes
# 2024-03-11 23:04:21                                                 No
# 2024-03-17 19:24:27                                                 No
# ...                                                                ...
# 2024-09-18 11:54:50                                                Yes
# 2024-10-31 20:07:16                                                Yes
# 2024-11-01 06:49:15                                                Yes
# 2024-10-31 19:43:47                                                Yes
# 2024-10-31 19:23:49                                                NaN
#
#                     How often are you using AI-based language models?  \
# Start Date
# 2024-03-05 20:06:43                                           Monthly
# 2024-03-11 13:31:43                                           Monthly
# 2024-03-11 16:27:36                                A few times/rarely
# 2024-03-11 23:04:21                                               NaN
# 2024-03-17 19:24:27                                               NaN
# ...                                                               ...
# 2024-09-18 11:54:50                                               NaN
# 2024-10-31 20:07:16                                            Weekly
# 2024-11-01 06:49:15                                            Weekly
# 2024-10-31 19:43:47                                           Monthly
# 2024-10-31 19:23:49                                               NaN
#
#                     How likely are you to use AI-based language models in the future?  \
# Start Date
# 2024-03-05 20:06:43                                    Somewhat likely
# 2024-03-11 13:31:43                                    Somewhat likely
# 2024-03-11 16:27:36                                   Extremely likely
# 2024-03-11 23:04:21                                  Somewhat unlikely
# 2024-03-17 19:24:27                                  Somewhat unlikely
# ...                                                                ...
# 2024-09-18 11:54:50                                                NaN
# 2024-10-31 20:07:16                                   Extremely likely
# 2024-11-01 06:49:15                                   Extremely likely
# 2024-10-31 19:43:47                                    Somewhat likely
# 2024-10-31 19:23:49                                                NaN
#
#                     In a single output given to you by an AI-based language model, on average how many edits have you needed to make?  \
# Start Date
# 2024-03-05 20:06:43                    Moderate editing (5-10 changes)
# 2024-03-11 13:31:43                    Moderate editing (5-10 changes)
# 2024-03-11 16:27:36              Minimal editing (less than 5 changes)
# 2024-03-11 23:04:21                                                NaN
# 2024-03-17 19:24:27                                                NaN
# ...                                                                ...
# 2024-09-18 11:54:50                                                NaN
# 2024-10-31 20:07:16                    Moderate editing (5-10 changes)
# 2024-11-01 06:49:15                    Moderate editing (5-10 changes)
# 2024-10-31 19:43:47              Minimal editing (less than 5 changes)
# 2024-10-31 19:23:49                                                NaN
#
#                     How do you think AI-based language models are impacting your learning?  \
# Start Date
# 2024-03-05 20:06:43                                          No impact
# 2024-03-11 13:31:43                                         Positively
# 2024-03-11 16:27:36                                         Positively
# 2024-03-11 23:04:21                                                NaN
# 2024-03-17 19:24:27                                                NaN
# ...                                                                ...
# 2024-09-18 11:54:50                                                NaN
# 2024-10-31 20:07:16                                         Positively
# 2024-11-01 06:49:15                                         Positively
# 2024-10-31 19:43:47                                         Positively
# 2024-10-31 19:23:49                                                NaN
#
#                     Which of the following large language models have you used? (Check all that apply) - Selected Choice  \
# Start Date
# 2024-03-05 20:06:43                                            ChatGPT
# 2024-03-11 13:31:43                                            ChatGPT
# 2024-03-11 16:27:36                                            ChatGPT
# 2024-03-11 23:04:21                                                NaN
# 2024-03-17 19:24:27                                                NaN
# ...                                                                ...
# 2024-09-18 11:54:50                                                NaN
# 2024-10-31 20:07:16                                      ChatGPT,GPT-4
# 2024-11-01 06:49:15                                            ChatGPT
# 2024-10-31 19:43:47                                            ChatGPT
# 2024-10-31 19:23:49                                                NaN
#
#                     How accurate did you find AI-based language models?
# Start Date
# 2024-03-05 20:06:43                 Somewhat accurate (a few mistakes)
# 2024-03-11 13:31:43                 Somewhat accurate (a few mistakes)
# 2024-03-11 16:27:36                 Somewhat accurate (a few mistakes)
# 2024-03-11 23:04:21                                                NaN
# 2024-03-17 19:24:27                                                NaN
# ...                                                                ...
# 2024-09-18 11:54:50                                                NaN
# 2024-10-31 20:07:16                 Somewhat accurate (a few mistakes)
# 2024-11-01 06:49:15                    Neither accurate nor inaccurate
# 2024-10-31 19:43:47                 Somewhat accurate (a few mistakes)
# 2024-10-31 19:23:49                                                NaN
#
# [61 rows x 7 columns]

# %%
# Clinical Groups Processing
clinical_col = 'Are you currently in the pre-clinical or clinical portion of your medical school? - Selected Choice'
clinical_perspective_feb_llm_use_df_clean_118= feb_llm_use_df_clean_118[feb_llm_use_df_clean_118[clinical_col] == 'Clinical'][opinion_cols_of_interest]
preclinical_perspective_feb_llm_use_df_clean_118 = feb_llm_use_df_clean_118[feb_llm_use_df_clean_118[clinical_col] == 'Pre-clinical'][opinion_cols_of_interest]


clin_demographics_feb_llm_use_df_clean_118= feb_llm_use_df_clean_118[feb_llm_use_df_clean_118[clinical_col] == 'Clinical'][demo_cols_of_interest]
preclin_demographics_feb_llm_use_df_clean_118 = feb_llm_use_df_clean_118[feb_llm_use_df_clean_118[clinical_col] == 'Pre-clinical'][demo_cols_of_interest]

# %%
# Function to process responses and calculate percentages iteratively
def process_responses(df):
    results = []
    
    for column in df.columns[:]:
        # Initialize a counter 
        counts = {}
        
        # Process the column
        for _, row in df.iterrows():
            value = row[column]
            # Check if the value is a string before processing
            if isinstance(value, str):
                responses = value.split(',') if ',' in value else [value]
                for response in responses:
                    response = response.strip()  # Clean up whitespace
                    counts[response] = counts.get(response, 0) + 1
        
        total_responses = sum(counts.values())
        
        for response, count in counts.items():
            percentage = (count / total_responses) * 100
            results.append({
                'Question': column,
                'Response': response,
                'Count': count,
                'Total Responses': total_responses,
                'Percentage': f"{percentage:.2f}%"
            })
    
    return pd.DataFrame(results)


# Process the DataFrame
# demographics_nov_clean_118_split_result_df = process_responses(demographics_nov_llm_use_df_clean_118)

##Process opinions on LLMs responses (both complete and incomplete survey responses)
op_nov_comp_split_result_df = process_responses(op_nov_llm_use_df_clean_118_comp)
op_nov_non_comp_split_result_df = process_responses(op_nov_llm_use_df_clean_118_non_comp)

#Process demographics on LLMs responses (both complete and incomplete survey responses)
demo_nov_comp_split_result_df = process_responses(demographics_nov_llm_use_df_clean_118_comp)
demo_nov_non_comp_split_result_df = process_responses(demographics_nov_llm_use_df_clean_118)
# perspective_nov_llm_use_df_clean_118_comp_split_result_df = process_responses(perspective_nov_llm_use_df_clean_118_comp)

# %%
# Function to process responses and calculate percentages iteratively
def process_responses(df):
    results = []
    
    for column in df.columns[:]:
        # Initialize a counter 
        counts = {}
        
        # Process the column
        for _, row in df.iterrows():
            value = row[column]
            # Check if the value is a string before processing
            if isinstance(value, str):
                responses = value.split(',') if ',' in value else [value]
                for response in responses:
                    response = response.strip()  # Clean up whitespace
                    counts[response] = counts.get(response, 0) + 1
        
        total_responses = sum(counts.values())
        
        for response, count in counts.items():
            percentage = (count / total_responses) * 100
            results.append({
                'Question': column,
                'Response': response,
                'Count': count,
                'Total Responses': total_responses,
                'Percentage': f"{percentage:.2f}%"
            })
    
    return pd.DataFrame(results)


# Process the DataFrame
# demographics_nov_clean_118_split_result_df = process_responses(demographics_nov_llm_use_df_clean_118)

##Process opinions on LLMs responses (both complete and incomplete survey responses)
op_feb_comp_split_result_df = process_responses(op_feb_llm_use_df_clean_118_comp)
op_feb_non_comp_split_result_df = process_responses(op_feb_llm_use_df_clean_118_non_comp)

#Process demographics on LLMs responses (both complete and incomplete survey responses)
demo_feb_comp_split_result_df = process_responses(demographics_feb_llm_use_df_clean_118_comp)
demo_feb_non_comp_split_result_df = process_responses(demographics_feb_llm_use_df_clean_118)
# perspective_nov_llm_use_df_clean_118_comp_split_result_df = process_responses(perspective_nov_llm_use_df_clean_118_comp)

# %%
##Process opinions on LLMs responses (both complete and incomplete survey responses)
clin_op_feb_split_result_df = process_responses(clinical_perspective_feb_llm_use_df_clean_118)
preclin_op_feb_split_result_df = process_responses(preclinical_perspective_feb_llm_use_df_clean_118)

#Process demographics on LLMs responses (both complete and incomplete survey responses)
clin_demo_feb_comp_split_result_df = process_responses(clin_demographics_feb_llm_use_df_clean_118)
preclin_demo_feb_split_result_df = process_responses(preclin_demographics_feb_llm_use_df_clean_118)
# perspective_nov_llm_use_df_clean_118_comp_split_result_df = process_responses(perspective_nov_llm_use_df_clean_118_comp)

# %%
#Function that formats columns for neatness
def clean_split_df(df):
    split_result_rows = []

    # Loop through each unique column
    for col in df['Question'].unique():
        group = df[df['Question'] == col]
        
        # Add the first response with the column name
        first_row = group.iloc[0].copy()
        split_result_rows.append(first_row)
        
        # Add subsequent responses without repeating the column name
        for idx in range(1, len(group)):
            row = group.iloc[idx].copy()
            row['Question'] = ''  # Clear the column name for subsequent rows
            split_result_rows.append(row)

    # Create a new DataFrame
    split_result_df = pd.DataFrame(split_result_rows)

    return split_result_df

# %%
#Formatting opionion LLM dfs for neatness
clean_opinion_non_comp = clean_split_df(op_nov_non_comp_split_result_df)
clean_opinion = clean_split_df(op_nov_comp_split_result_df)

# %%
#Formatting opionion LLM dfs for neatness
clean_opinion_non_comp = clean_split_df(op_feb_non_comp_split_result_df)
clean_opinion = clean_split_df(op_feb_comp_split_result_df)

# %%
#Formatting opionion LLM dfs for neatness
clean_opinion_clin= clean_split_df(clin_op_feb_split_result_df)
clean_opinion_preclin = clean_split_df(preclin_op_feb_split_result_df)

# %%
clean_opinion_clin
# Out:
#                                              Question  \
# 0   Have you used a large language model (e.g., Ch...
# 1
# 2   How often are you using AI-based language models?
# 3
# 4
# 5
# 6   How likely are you to use AI-based language mo...
# 7
# 8
# 9
# 10
# 11  In a single output given to you by an AI-based...
# 12
# 13
# 14
# 15  How do you think AI-based language models are ...
# 16
# 17  Which of the following large language models h...
# 18
# 19
# 20
# 21
# 22
# 23
# 24  How accurate did you find AI-based language mo...
# 25
# 26
#
#                                          Response  Count  Total Responses  \
# 0                                             Yes     51               60
# 1                                              No      9               60
# 2                                         Monthly     10               45
# 3                              A few times/rarely      4               45
# 4                                          Weekly     22               45
# 5                                           Daily      9               45
# 6                                 Somewhat likely     16               52
# 7                                Extremely likely     25               52
# 8                               Somewhat unlikely      5               52
# 9                     Neither likely nor unlikely      2               52
# 10                             Extremely unlikely      4               52
# 11                Moderate editing (5-10 changes)     23               45
# 12          Minimal editing (less than 5 changes)     13               45
# 13                                     No editing      6               45
# 14  Significant editing (greater than 10 changes)      3               45
# 15                                      No impact      4               45
# 16                                     Positively     41               45
# 17                                        ChatGPT     39               78
# 18                                    Google Bard     12               78
# 19                                          GPT-4     12               78
# 20                                      Bing Chat      7               78
# 21                                          Other      6               78
# 22                                         BioGPT      1               78
# 23                                   Doximity GPT      1               78
# 24             Somewhat accurate (a few mistakes)     27               45
# 25        Extremely accurate (almost no mistakes)      6               45
# 26                Neither accurate nor inaccurate     12               45
#
#    Percentage
# 0      85.00%
# 1      15.00%
# 2      22.22%
# 3       8.89%
# 4      48.89%
# 5      20.00%
# 6      30.77%
# 7      48.08%
# 8       9.62%
# 9       3.85%
# 10      7.69%
# 11     51.11%
# 12     28.89%
# 13     13.33%
# 14      6.67%
# 15      8.89%
# 16     91.11%
# 17     50.00%
# 18     15.38%
# 19     15.38%
# 20      8.97%
# 21      7.69%
# 22      1.28%
# 23      1.28%
# 24     60.00%
# 25     13.33%
# 26     26.67%

# %%
clean_opinion_preclin
# Out:
#                                              Question  \
# 0   Have you used a large language model (e.g., Ch...
# 1
# 2   How often are you using AI-based language models?
# 3
# 4
# 5
# 6   How likely are you to use AI-based language mo...
# 7
# 8
# 9
# 10  In a single output given to you by an AI-based...
# 11
# 12
# 13
# 14  How do you think AI-based language models are ...
# 15
# 16
# 17  Which of the following large language models h...
# 18
# 19
# 20
# 21
# 22
# 23  How accurate did you find AI-based language mo...
# 24
# 25
# 26
# 27
#
#                                              Response  Count  Total Responses  \
# 0                                                 Yes     37               41
# 1                                                  No      4               41
# 2                                              Weekly     10               30
# 3                                             Monthly      4               30
# 4                                  A few times/rarely      8               30
# 5                                               Daily      8               30
# 6                                    Extremely likely     17               31
# 7                                     Somewhat likely      8               31
# 8                                   Somewhat unlikely      5               31
# 9                         Neither likely nor unlikely      1               31
# 10              Minimal editing (less than 5 changes)     13               30
# 11                    Moderate editing (5-10 changes)      9               30
# 12                                         No editing      2               30
# 13      Significant editing (greater than 10 changes)      6               30
# 14                                         Positively     22               30
# 15                                          No impact      6               30
# 16                                         Negatively      2               30
# 17                                            ChatGPT     30               54
# 18                                              GPT-4      9               54
# 19                                          Bing Chat      4               54
# 20                                              Other      1               54
# 21                                        Google Bard      9               54
# 22                                       Doximity GPT      1               54
# 23                 Somewhat accurate (a few mistakes)     20               30
# 24                    Neither accurate nor inaccurate      5               30
# 25         Extremely inaccurate (completely unusable)      2               30
# 26  Somewhat inaccurate (too many mistakes to use ...      2               30
# 27            Extremely accurate (almost no mistakes)      1               30
#
#    Percentage
# 0      90.24%
# 1       9.76%
# 2      33.33%
# 3      13.33%
# 4      26.67%
# 5      26.67%
# 6      54.84%
# 7      25.81%
# 8      16.13%
# 9       3.23%
# 10     43.33%
# 11     30.00%
# 12      6.67%
# 13     20.00%
# 14     73.33%
# 15     20.00%
# 16      6.67%
# 17     55.56%
# 18     16.67%
# 19      7.41%
# 20      1.85%
# 21     16.67%
# 22      1.85%
# 23     66.67%
# 24     16.67%
# 25      6.67%
# 26      6.67%
# 27      3.33%

# %%
clean_opinion_clin
# Out:
#                                              Question  \
# 0   Have you used a large language model (e.g., Ch...
# 1
# 2   How often are you using AI-based language models?
# 3
# 4
# 5
# 6   How likely are you to use AI-based language mo...
# 7
# 8
# 9
# 10
# 11  In a single output given to you by an AI-based...
# 12
# 13
# 14
# 15  How do you think AI-based language models are ...
# 16
# 17  Which of the following large language models h...
# 18
# 19
# 20
# 21
# 22
# 23
# 24  How accurate did you find AI-based language mo...
# 25
# 26
#
#                                          Response  Count  Total Responses  \
# 0                                             Yes     51               60
# 1                                              No      9               60
# 2                                         Monthly     10               45
# 3                              A few times/rarely      4               45
# 4                                          Weekly     22               45
# 5                                           Daily      9               45
# 6                                 Somewhat likely     16               52
# 7                                Extremely likely     25               52
# 8                               Somewhat unlikely      5               52
# 9                     Neither likely nor unlikely      2               52
# 10                             Extremely unlikely      4               52
# 11                Moderate editing (5-10 changes)     23               45
# 12          Minimal editing (less than 5 changes)     13               45
# 13                                     No editing      6               45
# 14  Significant editing (greater than 10 changes)      3               45
# 15                                      No impact      4               45
# 16                                     Positively     41               45
# 17                                        ChatGPT     39               78
# 18                                    Google Bard     12               78
# 19                                          GPT-4     12               78
# 20                                      Bing Chat      7               78
# 21                                          Other      6               78
# 22                                         BioGPT      1               78
# 23                                   Doximity GPT      1               78
# 24             Somewhat accurate (a few mistakes)     27               45
# 25        Extremely accurate (almost no mistakes)      6               45
# 26                Neither accurate nor inaccurate     12               45
#
#    Percentage
# 0      85.00%
# 1      15.00%
# 2      22.22%
# 3       8.89%
# 4      48.89%
# 5      20.00%
# 6      30.77%
# 7      48.08%
# 8       9.62%
# 9       3.85%
# 10      7.69%
# 11     51.11%
# 12     28.89%
# 13     13.33%
# 14      6.67%
# 15      8.89%
# 16     91.11%
# 17     50.00%
# 18     15.38%
# 19     15.38%
# 20      8.97%
# 21      7.69%
# 22      1.28%
# 23      1.28%
# 24     60.00%
# 25     13.33%
# 26     26.67%

# %%
merged_clin_preclin_df = pd.merge(clean_opinion_preclin, clean_opinion_clin, how = 'outer', on="Response")
merged_clin_preclin_df
# Out:
#                                            Question_x  \
# 0   Have you used a large language model (e.g., Ch...
# 1
# 2   How often are you using AI-based language models?
# 3
# 4
# 5
# 6   How likely are you to use AI-based language mo...
# 7
# 8
# 9
# 10  In a single output given to you by an AI-based...
# 11
# 12
# 13
# 14  How do you think AI-based language models are ...
# 15
# 16
# 17  Which of the following large language models h...
# 18
# 19
# 20
# 21
# 22
# 23  How accurate did you find AI-based language mo...
# 24
# 25
# 26
# 27
# 28                                                NaN
# 29                                                NaN
#
#                                              Response  Count_x  \
# 0                                                 Yes     37.0
# 1                                                  No      4.0
# 2                                              Weekly     10.0
# 3                                             Monthly      4.0
# 4                                  A few times/rarely      8.0
# 5                                               Daily      8.0
# 6                                    Extremely likely     17.0
# 7                                     Somewhat likely      8.0
# 8                                   Somewhat unlikely      5.0
# 9                         Neither likely nor unlikely      1.0
# 10              Minimal editing (less than 5 changes)     13.0
# 11                    Moderate editing (5-10 changes)      9.0
# 12                                         No editing      2.0
# 13      Significant editing (greater than 10 changes)      6.0
# 14                                         Positively     22.0
# 15                                          No impact      6.0
# 16                                         Negatively      2.0
# 17                                            ChatGPT     30.0
# 18                                              GPT-4      9.0
# 19                                          Bing Chat      4.0
# 20                                              Other      1.0
# 21                                        Google Bard      9.0
# 22                                       Doximity GPT      1.0
# 23                 Somewhat accurate (a few mistakes)     20.0
# 24                    Neither accurate nor inaccurate      5.0
# 25         Extremely inaccurate (completely unusable)      2.0
# 26  Somewhat inaccurate (too many mistakes to use ...      2.0
# 27            Extremely accurate (almost no mistakes)      1.0
# 28                                 Extremely unlikely      NaN
# 29                                             BioGPT      NaN
#
#     Total Responses_x Percentage_x  \
# 0                41.0       90.24%
# 1                41.0        9.76%
# 2                30.0       33.33%
# 3                30.0       13.33%
# 4                30.0       26.67%
# 5                30.0       26.67%
# 6                31.0       54.84%
# 7                31.0       25.81%
# 8                31.0       16.13%
# 9                31.0        3.23%
# 10               30.0       43.33%
# 11               30.0       30.00%
# 12               30.0        6.67%
# 13               30.0       20.00%
# 14               30.0       73.33%
# 15               30.0       20.00%
# 16               30.0        6.67%
# 17               54.0       55.56%
# 18               54.0       16.67%
# 19               54.0        7.41%
# 20               54.0        1.85%
# 21               54.0       16.67%
# 22               54.0        1.85%
# 23               30.0       66.67%
# 24               30.0       16.67%
# 25               30.0        6.67%
# 26               30.0        6.67%
# 27               30.0        3.33%
# 28                NaN          NaN
# 29                NaN          NaN
#
#                                            Question_y  Count_y  \
# 0   Have you used a large language model (e.g., Ch...     51.0
# 1                                                          9.0
# 2                                                         22.0
# 3   How often are you using AI-based language models?     10.0
# 4                                                          4.0
# 5                                                          9.0
# 6                                                         25.0
# 7   How likely are you to use AI-based language mo...     16.0
# 8                                                          5.0
# 9                                                          2.0
# 10                                                        13.0
# 11  In a single output given to you by an AI-based...     23.0
# 12                                                         6.0
# 13                                                         3.0
# 14                                                        41.0
# 15  How do you think AI-based language models are ...      4.0
# 16                                                NaN      NaN
# 17  Which of the following large language models h...     39.0
# 18                                                        12.0
# 19                                                         7.0
# 20                                                         6.0
# 21                                                        12.0
# 22                                                         1.0
# 23  How accurate did you find AI-based language mo...     27.0
# 24                                                        12.0
# 25                                                NaN      NaN
# 26                                                NaN      NaN
# 27                                                         6.0
# 28                                                         4.0
# 29                                                         1.0
#
#     Total Responses_y Percentage_y
# 0                60.0       85.00%
# 1                60.0       15.00%
# 2                45.0       48.89%
# 3                45.0       22.22%
# 4                45.0        8.89%
# 5                45.0       20.00%
# 6                52.0       48.08%
# 7                52.0       30.77%
# 8                52.0        9.62%
# 9                52.0        3.85%
# 10               45.0       28.89%
# 11               45.0       51.11%
# 12               45.0       13.33%
# 13               45.0        6.67%
# 14               45.0       91.11%
# 15               45.0        8.89%
# 16                NaN          NaN
# 17               78.0       50.00%
# 18               78.0       15.38%
# 19               78.0        8.97%
# 20               78.0        7.69%
# 21               78.0       15.38%
# 22               78.0        1.28%
# 23               45.0       60.00%
# 24               45.0       26.67%
# 25                NaN          NaN
# 26                NaN          NaN
# 27               45.0       13.33%
# 28               52.0        7.69%
# 29               78.0        1.28%

# %%
merged_clin_preclin_clean = merged_clin_preclin_df.drop(['Count_x','Total Responses_x', 'Count_y', 'Total Responses_y', 'Question_y'],
                                  axis=1, inplace=False)

merged_clin_preclin_clean.columns = ['Question', 'Response', 'Clinical', 'Pre-clinical']
for col in ["Clinical", "Pre-clinical"]:
    merged_clin_preclin_clean[col] = merged_clin_preclin_clean[col].str.rstrip("%")   
    merged_clin_preclin_clean[col] = pd.to_numeric(merged_clin_preclin_clean[col])

# %%
merged_clin_preclin_clean
# Out:
#                                              Question  \
# 0   Have you used a large language model (e.g., Ch...
# 1
# 2   How often are you using AI-based language models?
# 3
# 4
# 5
# 6   How likely are you to use AI-based language mo...
# 7
# 8
# 9
# 10  In a single output given to you by an AI-based...
# 11
# 12
# 13
# 14  How do you think AI-based language models are ...
# 15
# 16
# 17  Which of the following large language models h...
# 18
# 19
# 20
# 21
# 22
# 23  How accurate did you find AI-based language mo...
# 24
# 25
# 26
# 27
# 28                                                NaN
# 29                                                NaN
#
#                                              Response  Clinical  Pre-clinical
# 0                                                 Yes     90.24         85.00
# 1                                                  No      9.76         15.00
# 2                                              Weekly     33.33         48.89
# 3                                             Monthly     13.33         22.22
# 4                                  A few times/rarely     26.67          8.89
# 5                                               Daily     26.67         20.00
# 6                                    Extremely likely     54.84         48.08
# 7                                     Somewhat likely     25.81         30.77
# 8                                   Somewhat unlikely     16.13          9.62
# 9                         Neither likely nor unlikely      3.23          3.85
# 10              Minimal editing (less than 5 changes)     43.33         28.89
# 11                    Moderate editing (5-10 changes)     30.00         51.11
# 12                                         No editing      6.67         13.33
# 13      Significant editing (greater than 10 changes)     20.00          6.67
# 14                                         Positively     73.33         91.11
# 15                                          No impact     20.00          8.89
# 16                                         Negatively      6.67           NaN
# 17                                            ChatGPT     55.56         50.00
# 18                                              GPT-4     16.67         15.38
# 19                                          Bing Chat      7.41          8.97
# 20                                              Other      1.85          7.69
# 21                                        Google Bard     16.67         15.38
# 22                                       Doximity GPT      1.85          1.28
# 23                 Somewhat accurate (a few mistakes)     66.67         60.00
# 24                    Neither accurate nor inaccurate     16.67         26.67
# 25         Extremely inaccurate (completely unusable)      6.67           NaN
# 26  Somewhat inaccurate (too many mistakes to use ...      6.67           NaN
# 27            Extremely accurate (almost no mistakes)      3.33         13.33
# 28                                 Extremely unlikely       NaN          7.69
# 29                                             BioGPT       NaN          1.28

# %%
merged_clin_preclin_clean.to_csv("pre_clin_clin_op.csv", encoding='utf-8', index=False)

# %%
import seaborn as sns

# %%
# Plot LLM Freq 
sns.barplot
plt.rcParams['font.family'] = 'Arial'
sns.set_palette("pastel") # color palette

# Plot parameters
bar_width = 0.4
x = np.arange(len(merged_LLM_freq["Response"]))

# Plot dataframes
plt.bar(x - bar_width / 2, merged_LLM_freq["Pre-clinical"], width=bar_width, label="Pre-clinical (n=38)")
plt.bar(x + bar_width / 2, merged_LLM_freq["Clinical"], width=bar_width, label="Clinical (n=52)")

# Labels
plt.ylabel("Percentage of Responses")
plt.title("How often are you using AI-based language models?")
plt.xticks(x, merged_LLM_freq["Response"]) 
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
##Demographics -- include those who completed the survey; The people who said no should not be included in further analysis. 
##Correect way to do demographics + computations is for the number of people that compelted the survey.

# %%
# demo_nov_comp_split_result_df

# %%
# demo_nov_non_comp_split_result_df
# Out:
#                                              Question  \
# 0   What type of community is your medical school in?
# 1   What type of community is your medical school in?
# 2   What type of community is your medical school in?
# 3   Is your medical school in the U.S. / a U.S. te...
# 4   Is your medical school in the U.S. / a U.S. te...
# 5   Are you currently in the pre-clinical or clini...
# 6   Are you currently in the pre-clinical or clini...
# 7   Are you currently in the pre-clinical or clini...
# 8              What is your gender? - Selected Choice
# 9              What is your gender? - Selected Choice
# 10             What is your gender? - Selected Choice
# 11             What is your gender? - Selected Choice
# 12    Are you of Spanish, Hispanic, or Latino origin?
# 13    Are you of Spanish, Hispanic, or Latino origin?
# 14  How would you describe your race? - Selected C...
# 15  How would you describe your race? - Selected C...
# 16  How would you describe your race? - Selected C...
# 17  How would you describe your race? - Selected C...
# 18  How would you describe your race? - Selected C...
# 19  How would you describe your race? - Selected C...
#
#                                      Response  Count  Total Responses  \
# 0                                       Urban     81              105
# 1                                    Suburban     16              105
# 2                                       Rural      8              105
# 3                                         Yes     92              118
# 4                                          No     26              118
# 5                                    Clinical     61              105
# 6                                Pre-clinical     40              105
# 7                                       Other      4              105
# 8                                      Female     36               86
# 9                                        Male     41               86
# 10                                 Non-binary      4               86
# 11                          Prefer not to say      5               86
# 12                                         No     76               86
# 13                                        Yes     10               86
# 14                                      Other      8               90
# 15                         White or Caucasian     27               90
# 16                                      Asian     28               90
# 17                  Black or African American     20               90
# 18                          Prefer not to say      4               90
# 19  Native Hawaiian or Other Pacific Islander      3               90
#
#    Percentage
# 0      77.14%
# 1      15.24%
# 2       7.62%
# 3      77.97%
# 4      22.03%
# 5      58.10%
# 6      38.10%
# 7       3.81%
# 8      41.86%
# 9      47.67%
# 10      4.65%
# 11      5.81%
# 12     88.37%
# 13     11.63%
# 14      8.89%
# 15     30.00%
# 16     31.11%
# 17     22.22%
# 18      4.44%
# 19      3.33%

# %%
clean_demo = clean_split_df(demo_nov_comp_split_result_df)
# clean_demo
# Out:
#                                              Question  \
# 0   What type of community is your medical school in?
# 1
# 2
# 3   Is your medical school in the U.S. / a U.S. te...
# 4
# 5   Are you currently in the pre-clinical or clini...
# 6
# 7
# 8              What is your gender? - Selected Choice
# 9
# 10
# 11
# 12    Are you of Spanish, Hispanic, or Latino origin?
# 13
# 14  How would you describe your race? - Selected C...
# 15
# 16
# 17
# 18
# 19
#
#                                      Response  Count  Total Responses  \
# 0                                       Urban     70               86
# 1                                    Suburban     12               86
# 2                                       Rural      4               86
# 3                                         Yes     71               86
# 4                                          No     15               86
# 5                                    Clinical     52               86
# 6                                Pre-clinical     31               86
# 7                                       Other      3               86
# 8                                      Female     36               86
# 9                                        Male     41               86
# 10                                 Non-binary      4               86
# 11                          Prefer not to say      5               86
# 12                                         No     76               86
# 13                                        Yes     10               86
# 14                                      Other      8               90
# 15                         White or Caucasian     27               90
# 16                                      Asian     28               90
# 17                  Black or African American     20               90
# 18                          Prefer not to say      4               90
# 19  Native Hawaiian or Other Pacific Islander      3               90
#
#    Percentage
# 0      81.40%
# 1      13.95%
# 2       4.65%
# 3      82.56%
# 4      17.44%
# 5      60.47%
# 6      36.05%
# 7       3.49%
# 8      41.86%
# 9      47.67%
# 10      4.65%
# 11      5.81%
# 12     88.37%
# 13     11.63%
# 14      8.89%
# 15     30.00%
# 16     31.11%
# 17     22.22%
# 18      4.44%
# 19      3.33%

# %%
clean_demo = clean_split_df(demo_feb_comp_split_result_df)
clean_demo
# Out:
#                                              Question  \
# 0   What type of community is your medical school in?
# 1
# 2
# 3   Is your medical school in the U.S. / a U.S. te...
# 4
# 5   Are you currently in the pre-clinical or clini...
# 6
# 7
# 8              What is your gender? - Selected Choice
# 9
# 10
# 11
# 12    Are you of Spanish, Hispanic, or Latino origin?
# 13
# 14  How would you describe your race? - Selected C...
# 15
# 16
# 17
# 18
# 19
#
#                                      Response  Count  Total Responses  \
# 0                                       Urban     70               86
# 1                                    Suburban     12               86
# 2                                       Rural      4               86
# 3                                         Yes     71               86
# 4                                          No     15               86
# 5                                    Clinical     52               86
# 6                                Pre-clinical     31               86
# 7                                       Other      3               86
# 8                                      Female     36               86
# 9                                        Male     41               86
# 10                                 Non-binary      4               86
# 11                          Prefer not to say      5               86
# 12                                         No     76               86
# 13                                        Yes     10               86
# 14                                      Other      8               90
# 15                         White or Caucasian     27               90
# 16                                      Asian     28               90
# 17                  Black or African American     20               90
# 18                          Prefer not to say      4               90
# 19  Native Hawaiian or Other Pacific Islander      3               90
#
#    Percentage
# 0      81.40%
# 1      13.95%
# 2       4.65%
# 3      82.56%
# 4      17.44%
# 5      60.47%
# 6      36.05%
# 7       3.49%
# 8      41.86%
# 9      47.67%
# 10      4.65%
# 11      5.81%
# 12     88.37%
# 13     11.63%
# 14      8.89%
# 15     30.00%
# 16     31.11%
# 17     22.22%
# 18      4.44%
# 19      3.33%

# %%
clean_demo_non_comp = clean_split_df(demo_nov_non_comp_split_result_df)
# clean_demo_non_comp
# Out:
#                                              Question  \
# 0   What type of community is your medical school in?
# 1
# 2
# 3   Is your medical school in the U.S. / a U.S. te...
# 4
# 5   Are you currently in the pre-clinical or clini...
# 6
# 7
# 8              What is your gender? - Selected Choice
# 9
# 10
# 11
# 12    Are you of Spanish, Hispanic, or Latino origin?
# 13
# 14  How would you describe your race? - Selected C...
# 15
# 16
# 17
# 18
# 19
#
#                                      Response  Count  Total Responses  \
# 0                                       Urban     81              105
# 1                                    Suburban     16              105
# 2                                       Rural      8              105
# 3                                         Yes     92              118
# 4                                          No     26              118
# 5                                    Clinical     61              105
# 6                                Pre-clinical     40              105
# 7                                       Other      4              105
# 8                                      Female     36               86
# 9                                        Male     41               86
# 10                                 Non-binary      4               86
# 11                          Prefer not to say      5               86
# 12                                         No     76               86
# 13                                        Yes     10               86
# 14                                      Other      8               90
# 15                         White or Caucasian     27               90
# 16                                      Asian     28               90
# 17                  Black or African American     20               90
# 18                          Prefer not to say      4               90
# 19  Native Hawaiian or Other Pacific Islander      3               90
#
#    Percentage
# 0      77.14%
# 1      15.24%
# 2       7.62%
# 3      77.97%
# 4      22.03%
# 5      58.10%
# 6      38.10%
# 7       3.81%
# 8      41.86%
# 9      47.67%
# 10      4.65%
# 11      5.81%
# 12     88.37%
# 13     11.63%
# 14      8.89%
# 15     30.00%
# 16     31.11%
# 17     22.22%
# 18      4.44%
# 19      3.33%

# %%
clean_demo_non_comp = clean_split_df(demo_feb_non_comp_split_result_df)
clean_demo_non_comp
# Out:
#                                              Question  \
# 0   What type of community is your medical school in?
# 1
# 2
# 3   Is your medical school in the U.S. / a U.S. te...
# 4
# 5   Are you currently in the pre-clinical or clini...
# 6
# 7
# 8              What is your gender? - Selected Choice
# 9
# 10
# 11
# 12    Are you of Spanish, Hispanic, or Latino origin?
# 13
# 14  How would you describe your race? - Selected C...
# 15
# 16
# 17
# 18
# 19
#
#                                      Response  Count  Total Responses  \
# 0                                       Urban     82              106
# 1                                    Suburban     16              106
# 2                                       Rural      8              106
# 3                                         Yes     93              120
# 4                                          No     27              120
# 5                                    Clinical     61              106
# 6                                Pre-clinical     41              106
# 7                                       Other      4              106
# 8                                      Female     36               86
# 9                                        Male     41               86
# 10                                 Non-binary      4               86
# 11                          Prefer not to say      5               86
# 12                                         No     76               86
# 13                                        Yes     10               86
# 14                                      Other      8               90
# 15                         White or Caucasian     27               90
# 16                                      Asian     28               90
# 17                  Black or African American     20               90
# 18                          Prefer not to say      4               90
# 19  Native Hawaiian or Other Pacific Islander      3               90
#
#    Percentage
# 0      77.36%
# 1      15.09%
# 2       7.55%
# 3      77.50%
# 4      22.50%
# 5      57.55%
# 6      38.68%
# 7       3.77%
# 8      41.86%
# 9      47.67%
# 10      4.65%
# 11      5.81%
# 12     88.37%
# 13     11.63%
# 14      8.89%
# 15     30.00%
# 16     31.11%
# 17     22.22%
# 18      4.44%
# 19      3.33%

# %%
clean_demo_non_comp.to_csv("LLM_perspectives_data_split_non_comp_Nov.csv", encoding='utf-8', index=False)

# %%
clean_demo_non_comp.to_csv("LLM_perspectives_data_split_non_comp_Feb.csv", encoding='utf-8', index=False)

# %%
clean_demo.to_csv("LLM_perspectives_data_split_Nov.csv", encoding='utf-8', index=False)

# %%
clean_opinion.to_csv("LLM_opinions_data_split_Nov_comp.csv", encoding='utf-8', index=False)

# %%
clean_opinion_non_comp.to_csv("LLM_opinions_data_split_Feb_non_comp.csv", encoding='utf-8', index=False)

# %%
# #Characteristic Test result rows
# split_result_rows = []

# # Loop through each unique column
# for col in demographics_nov_llm_use_df_clean_118_split_result_df['Question'].unique():
#     group = demographics_nov_llm_use_df_clean_118_split_result_df[demographics_nov_llm_use_df_clean_118_split_result_df['Question'] == col]
    
#     # Add the first response with the column name
#     first_row = group.iloc[0].copy()
#     split_result_rows.append(first_row)
    
#     # Add subsequent responses without repeating the column name
#     for idx in range(1, len(group)):
#         row = group.iloc[idx].copy()
#         row['Question'] = ''  # Clear the column name for subsequent rows
#         split_result_rows.append(row)

# # Create a new DataFrame
# demo_split_result_df = pd.DataFrame(split_result_rows)

# # Display the final DataFrame
# demo_split_result_df.head(70)
# Out:
#                                              Question  \
# 0   Is your medical school in the U.S. / a U.S. te...
# 1
# 2   Are you currently in the pre-clinical or clini...
# 3
# 4
# 5              What is your gender? - Selected Choice
# 6
# 7
# 8
# 9     Are you of Spanish, Hispanic, or Latino origin?
# 10
# 11  How would you describe your race? - Selected C...
# 12
# 13
# 14
# 15
# 16
#
#                                      Response  Count  Total Responses  \
# 0                                         Yes     92              118
# 1                                          No     26              118
# 2                                    Clinical     61              105
# 3                                Pre-clinical     40              105
# 4                                       Other      4              105
# 5                                      Female     36               86
# 6                                        Male     41               86
# 7                                  Non-binary      4               86
# 8                           Prefer not to say      5               86
# 9                                          No     76               86
# 10                                        Yes     10               86
# 11                                      Other      8               90
# 12                         White or Caucasian     27               90
# 13                                      Asian     28               90
# 14                  Black or African American     20               90
# 15                          Prefer not to say      4               90
# 16  Native Hawaiian or Other Pacific Islander      3               90
#
#    Percentage
# 0      77.97%
# 1      22.03%
# 2      58.10%
# 3      38.10%
# 4       3.81%
# 5      41.86%
# 6      47.67%
# 7       4.65%
# 8       5.81%
# 9      88.37%
# 10     11.63%
# 11      8.89%
# 12     30.00%
# 13     31.11%
# 14     22.22%
# 15      4.44%
# 16      3.33%

# %%
clin_op_feb_split_result_df
# Out:
#                                              Question  \
# 0   Have you used a large language model (e.g., Ch...
# 1   Have you used a large language model (e.g., Ch...
# 2   How often are you using AI-based language models?
# 3   How often are you using AI-based language models?
# 4   How often are you using AI-based language models?
# 5   How often are you using AI-based language models?
# 6   How likely are you to use AI-based language mo...
# 7   How likely are you to use AI-based language mo...
# 8   How likely are you to use AI-based language mo...
# 9   How likely are you to use AI-based language mo...
# 10  How likely are you to use AI-based language mo...
# 11  In a single output given to you by an AI-based...
# 12  In a single output given to you by an AI-based...
# 13  In a single output given to you by an AI-based...
# 14  In a single output given to you by an AI-based...
# 15  How do you think AI-based language models are ...
# 16  How do you think AI-based language models are ...
# 17  Which of the following large language models h...
# 18  Which of the following large language models h...
# 19  Which of the following large language models h...
# 20  Which of the following large language models h...
# 21  Which of the following large language models h...
# 22  Which of the following large language models h...
# 23  Which of the following large language models h...
# 24  How accurate did you find AI-based language mo...
# 25  How accurate did you find AI-based language mo...
# 26  How accurate did you find AI-based language mo...
#
#                                          Response  Count  Total Responses  \
# 0                                             Yes     51               60
# 1                                              No      9               60
# 2                                         Monthly     10               45
# 3                              A few times/rarely      4               45
# 4                                          Weekly     22               45
# 5                                           Daily      9               45
# 6                                 Somewhat likely     16               52
# 7                                Extremely likely     25               52
# 8                               Somewhat unlikely      5               52
# 9                     Neither likely nor unlikely      2               52
# 10                             Extremely unlikely      4               52
# 11                Moderate editing (5-10 changes)     23               45
# 12          Minimal editing (less than 5 changes)     13               45
# 13                                     No editing      6               45
# 14  Significant editing (greater than 10 changes)      3               45
# 15                                      No impact      4               45
# 16                                     Positively     41               45
# 17                                        ChatGPT     39               78
# 18                                    Google Bard     12               78
# 19                                          GPT-4     12               78
# 20                                      Bing Chat      7               78
# 21                                          Other      6               78
# 22                                         BioGPT      1               78
# 23                                   Doximity GPT      1               78
# 24             Somewhat accurate (a few mistakes)     27               45
# 25        Extremely accurate (almost no mistakes)      6               45
# 26                Neither accurate nor inaccurate     12               45
#
#    Percentage
# 0      85.00%
# 1      15.00%
# 2      22.22%
# 3       8.89%
# 4      48.89%
# 5      20.00%
# 6      30.77%
# 7      48.08%
# 8       9.62%
# 9       3.85%
# 10      7.69%
# 11     51.11%
# 12     28.89%
# 13     13.33%
# 14      6.67%
# 15      8.89%
# 16     91.11%
# 17     50.00%
# 18     15.38%
# 19     15.38%
# 20      8.97%
# 21      7.69%
# 22      1.28%
# 23      1.28%
# 24     60.00%
# 25     13.33%
# 26     26.67%

# %%
preclin_op_feb_split_result_df
# Out:
#                                              Question  \
# 0   Have you used a large language model (e.g., Ch...
# 1   Have you used a large language model (e.g., Ch...
# 2   How often are you using AI-based language models?
# 3   How often are you using AI-based language models?
# 4   How often are you using AI-based language models?
# 5   How often are you using AI-based language models?
# 6   How likely are you to use AI-based language mo...
# 7   How likely are you to use AI-based language mo...
# 8   How likely are you to use AI-based language mo...
# 9   How likely are you to use AI-based language mo...
# 10  In a single output given to you by an AI-based...
# 11  In a single output given to you by an AI-based...
# 12  In a single output given to you by an AI-based...
# 13  In a single output given to you by an AI-based...
# 14  How do you think AI-based language models are ...
# 15  How do you think AI-based language models are ...
# 16  How do you think AI-based language models are ...
# 17  Which of the following large language models h...
# 18  Which of the following large language models h...
# 19  Which of the following large language models h...
# 20  Which of the following large language models h...
# 21  Which of the following large language models h...
# 22  Which of the following large language models h...
# 23  How accurate did you find AI-based language mo...
# 24  How accurate did you find AI-based language mo...
# 25  How accurate did you find AI-based language mo...
# 26  How accurate did you find AI-based language mo...
# 27  How accurate did you find AI-based language mo...
#
#                                              Response  Count  Total Responses  \
# 0                                                 Yes     37               41
# 1                                                  No      4               41
# 2                                              Weekly     10               30
# 3                                             Monthly      4               30
# 4                                  A few times/rarely      8               30
# 5                                               Daily      8               30
# 6                                    Extremely likely     17               31
# 7                                     Somewhat likely      8               31
# 8                                   Somewhat unlikely      5               31
# 9                         Neither likely nor unlikely      1               31
# 10              Minimal editing (less than 5 changes)     13               30
# 11                    Moderate editing (5-10 changes)      9               30
# 12                                         No editing      2               30
# 13      Significant editing (greater than 10 changes)      6               30
# 14                                         Positively     22               30
# 15                                          No impact      6               30
# 16                                         Negatively      2               30
# 17                                            ChatGPT     30               54
# 18                                              GPT-4      9               54
# 19                                          Bing Chat      4               54
# 20                                              Other      1               54
# 21                                        Google Bard      9               54
# 22                                       Doximity GPT      1               54
# 23                 Somewhat accurate (a few mistakes)     20               30
# 24                    Neither accurate nor inaccurate      5               30
# 25         Extremely inaccurate (completely unusable)      2               30
# 26  Somewhat inaccurate (too many mistakes to use ...      2               30
# 27            Extremely accurate (almost no mistakes)      1               30
#
#    Percentage
# 0      90.24%
# 1       9.76%
# 2      33.33%
# 3      13.33%
# 4      26.67%
# 5      26.67%
# 6      54.84%
# 7      25.81%
# 8      16.13%
# 9       3.23%
# 10     43.33%
# 11     30.00%
# 12      6.67%
# 13     20.00%
# 14     73.33%
# 15     20.00%
# 16      6.67%
# 17     55.56%
# 18     16.67%
# 19      7.41%
# 20      1.85%
# 21     16.67%
# 22      1.85%
# 23     66.67%
# 24     16.67%
# 25      6.67%
# 26      6.67%
# 27      3.33%
